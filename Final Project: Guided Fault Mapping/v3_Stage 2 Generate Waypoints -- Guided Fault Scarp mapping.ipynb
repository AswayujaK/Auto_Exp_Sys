# %%
## Maddie Schwarz, Mindy Zuckerman, Hafiz Abdel, Aswayuja Koduri 
#4/21/2022  SES 598 Autonomous Exploration Systems

from osgeo import gdal, gdal_array
from osgeo import osr
import pandas as pd

import subprocess
import os

import numpy as np
import matplotlib.pyplot as plt

from osgeo import ogr
import geopandas as gpd 
from shapely.geometry import shape, Polygon
from centerline.geometry import Centerline

# %%
shapefile_name = "b1m_g30_KM2_poly.shp"

# %%
# Read the fault zone shapefile (a multi-polygon) using geopandas
# Display the attributes table

shapefile = gpd.read_file(shapefile_name)
print(shapefile)
# Out:
#     DN    Area                                           geometry
# 0  1.0  5812.0  POLYGON ((-12.33231 83.42529, 15.66769 83.4252...
# 1  0.0     NaN  POLYGON ((-76.33231 83.42529, -12.33231 83.425...

# %%
shapefile.geom_type
# Out:
# 0    Polygon
# 1    Polygon
# dtype: object

# %%
# extract row containing scarp polygon from df
# https://stackoverflow.com/questions/46307490/how-can-i-extract-the-nth-row-of-a-pandas-data-frame-as-a-pandas-data-frame

scarp = shapefile.iloc[[0]]
scarp
#scarp.geom_type
# Out:
#     DN    Area                                           geometry
# 0  1.0  5812.0  POLYGON ((-12.33231 83.42529, 15.66769 83.4252...

# %%
# save just the scarp as a new polygon shapefile
scarp.to_file('b1m_scarp_poly.shp')

# %%
scarp_shp = gpd.read_file("b1m_scarp_poly.shp")

scarp_geom = scarp['geometry']
scarp_geom
#type(scarp_geom)
# Out:
# 0    POLYGON ((-12.33231 83.42529, 15.66769 83.4252...
# Name: geometry, dtype: geometry

# %%
# access the shapely object stored in the geopandas datafram ('geometry' column)
# https://gis.stackexchange.com/questions/404299/how-to-convert-string-type-to-shapely-object

in_polygon = scarp_shp.geometry[0] 
in_polygon

# %%
# Check the data type of the polygon -- needs to be 'shapely' to input into centerline class
type(in_polygon)
# Out:
# shapely.geometry.polygon.Polygon

# %%
# get polygon coordinates
# upper edge of polygon is start: (15.667686462402344, 83.42528533935547)
# end:(60.667686462402344, -67.57471466064453),
in_polygon.exterior.coords[:-1]
# Out:
# [(-12.332313537597656, 83.42528533935547),
#  (15.667686462402344, 83.42528533935547),
#  (15.667686462402344, 82.42528533935547),
#  (17.667686462402344, 82.42528533935547),
#  (17.667686462402344, 81.42528533935547),
#  (19.667686462402344, 81.42528533935547),
#  (19.667686462402344, 80.42528533935547),
#  (20.667686462402344, 80.42528533935547),
#  (20.667686462402344, 79.42528533935547),
#  (21.667686462402344, 79.42528533935547),
#  (21.667686462402344, 78.42528533935547),
#  (22.667686462402344, 78.42528533935547),
#  (22.667686462402344, 75.42528533935547),
#  (21.667686462402344, 75.42528533935547),
#  (21.667686462402344, 74.42528533935547),
#  (20.667686462402344, 74.42528533935547),
#  (20.667686462402344, 72.42528533935547),
#  (19.667686462402344, 72.42528533935547),
#  (19.667686462402344, 71.42528533935547),
#  (18.667686462402344, 71.42528533935547),
#  (18.667686462402344, 64.42528533935547),
#  (19.667686462402344, 64.42528533935547),
#  (19.667686462402344, 61.42528533935547),
#  (20.667686462402344, 61.42528533935547),
#  (20.667686462402344, 58.42528533935547),
#  (21.667686462402344, 58.42528533935547),
#  (21.667686462402344, 54.42528533935547),
#  (22.667686462402344, 54.42528533935547),
#  (22.667686462402344, 51.42528533935547),
#  (23.667686462402344, 51.42528533935547),
#  (23.667686462402344, 48.42528533935547),
#  (24.667686462402344, 48.42528533935547),
#  (24.667686462402344, 46.42528533935547),
#  (25.667686462402344, 46.42528533935547),
#  (25.667686462402344, 45.42528533935547),
#  (26.667686462402344, 45.42528533935547),
#  (26.667686462402344, 43.42528533935547),
#  (27.667686462402344, 43.42528533935547),
#  (27.667686462402344, 41.42528533935547),
#  (28.667686462402344, 41.42528533935547),
#  (28.667686462402344, 39.42528533935547),
#  (29.667686462402344, 39.42528533935547),
#  (29.667686462402344, 36.42528533935547),
#  (30.667686462402344, 36.42528533935547),
#  (30.667686462402344, 26.42528533935547),
#  (31.667686462402344, 26.42528533935547),
#  (31.667686462402344, 24.42528533935547),
#  (32.667686462402344, 24.42528533935547),
#  (32.667686462402344, 22.42528533935547),
#  (33.667686462402344, 22.42528533935547),
#  (33.667686462402344, 21.42528533935547),
#  (34.667686462402344, 21.42528533935547),
#  (34.667686462402344, 19.42528533935547),
#  (35.667686462402344, 19.42528533935547),
#  (35.667686462402344, 17.42528533935547),
#  (36.667686462402344, 17.42528533935547),
#  (36.667686462402344, 15.425285339355469),
#  (37.667686462402344, 15.425285339355469),
#  (37.667686462402344, 12.425285339355469),
#  (38.667686462402344, 12.425285339355469),
#  (38.667686462402344, 10.425285339355469),
#  (39.667686462402344, 10.425285339355469),
#  (39.667686462402344, 6.425285339355469),
#  (40.667686462402344, 6.425285339355469),
#  (40.667686462402344, 2.4252853393554688),
#  (41.667686462402344, 2.4252853393554688),
#  (41.667686462402344, -3.5747146606445312),
#  (42.667686462402344, -3.5747146606445312),
#  (42.667686462402344, -7.574714660644531),
#  (43.667686462402344, -7.574714660644531),
#  (43.667686462402344, -10.574714660644531),
#  (44.667686462402344, -10.574714660644531),
#  (44.667686462402344, -13.574714660644531),
#  (45.667686462402344, -13.574714660644531),
#  (45.667686462402344, -16.57471466064453),
#  (46.667686462402344, -16.57471466064453),
#  (46.667686462402344, -19.57471466064453),
#  (47.667686462402344, -19.57471466064453),
#  (47.667686462402344, -22.57471466064453),
#  (48.667686462402344, -22.57471466064453),
#  (48.667686462402344, -25.57471466064453),
#  (49.667686462402344, -25.57471466064453),
#  (49.667686462402344, -28.57471466064453),
#  (50.667686462402344, -28.57471466064453),
#  (50.667686462402344, -31.57471466064453),
#  (51.667686462402344, -31.57471466064453),
#  (51.667686462402344, -34.57471466064453),
#  (52.667686462402344, -34.57471466064453),
#  (52.667686462402344, -37.57471466064453),
#  (53.667686462402344, -37.57471466064453),
#  (53.667686462402344, -39.57471466064453),
#  (54.667686462402344, -39.57471466064453),
#  (54.667686462402344, -42.57471466064453),
#  (55.667686462402344, -42.57471466064453),
#  (55.667686462402344, -44.57471466064453),
#  (56.667686462402344, -44.57471466064453),
#  (56.667686462402344, -47.57471466064453),
#  (57.667686462402344, -47.57471466064453),
#  (57.667686462402344, -50.57471466064453),
#  (58.667686462402344, -50.57471466064453),
#  (58.667686462402344, -54.57471466064453),
#  (59.667686462402344, -54.57471466064453),
#  (59.667686462402344, -57.57471466064453),
#  (60.667686462402344, -57.57471466064453),
#  (60.667686462402344, -58.57471466064453),
#  (61.667686462402344, -58.57471466064453),
#  (61.667686462402344, -60.57471466064453),
#  (62.667686462402344, -60.57471466064453),
#  (62.667686462402344, -65.57471466064453),
#  (61.667686462402344, -65.57471466064453),
#  (61.667686462402344, -66.57471466064453),
#  (60.667686462402344, -66.57471466064453),
#  (60.667686462402344, -67.57471466064453),
#  (59.667686462402344, -67.57471466064453),
#  (58.667686462402344, -67.57471466064453),
#  (58.667686462402344, -68.57471466064453),
#  (57.667686462402344, -68.57471466064453),
#  (56.667686462402344, -68.57471466064453),
#  (56.667686462402344, -69.57471466064453),
#  (55.667686462402344, -69.57471466064453),
#  (51.667686462402344, -69.57471466064453),
#  (51.667686462402344, -70.57471466064453),
#  (28.667686462402344, -70.57471466064453),
#  (28.667686462402344, -69.57471466064453),
#  (25.667686462402344, -69.57471466064453),
#  (25.667686462402344, -66.57471466064453),
#  (24.667686462402344, -66.57471466064453),
#  (24.667686462402344, -61.57471466064453),
#  (23.667686462402344, -61.57471466064453),
#  (23.667686462402344, -59.57471466064453),
#  (22.667686462402344, -59.57471466064453),
#  (22.667686462402344, -57.57471466064453),
#  (21.667686462402344, -57.57471466064453),
#  (21.667686462402344, -55.57471466064453),
#  (20.667686462402344, -55.57471466064453),
#  (20.667686462402344, -52.57471466064453),
#  (19.667686462402344, -52.57471466064453),
#  (19.667686462402344, -49.57471466064453),
#  (18.667686462402344, -49.57471466064453),
#  (18.667686462402344, -44.57471466064453),
#  (17.667686462402344, -44.57471466064453),
#  (17.667686462402344, -38.57471466064453),
#  (16.667686462402344, -38.57471466064453),
#  (16.667686462402344, -35.57471466064453),
#  (15.667686462402344, -35.57471466064453),
#  (15.667686462402344, -33.57471466064453),
#  (14.667686462402344, -33.57471466064453),
#  (14.667686462402344, -31.57471466064453),
#  (13.667686462402344, -31.57471466064453),
#  (13.667686462402344, -28.57471466064453),
#  (12.667686462402344, -28.57471466064453),
#  (12.667686462402344, -26.57471466064453),
#  (11.667686462402344, -26.57471466064453),
#  (11.667686462402344, -23.57471466064453),
#  (10.667686462402344, -23.57471466064453),
#  (10.667686462402344, -20.57471466064453),
#  (9.667686462402344, -20.57471466064453),
#  (9.667686462402344, -17.57471466064453),
#  (8.667686462402344, -17.57471466064453),
#  (8.667686462402344, -14.574714660644531),
#  (7.667686462402344, -14.574714660644531),
#  (7.667686462402344, -12.574714660644531),
#  (6.667686462402344, -12.574714660644531),
#  (6.667686462402344, -9.574714660644531),
#  (5.667686462402344, -9.574714660644531),
#  (5.667686462402344, -7.574714660644531),
#  (4.667686462402344, -7.574714660644531),
#  (4.667686462402344, -4.574714660644531),
#  (3.6676864624023438, -4.574714660644531),
#  (3.6676864624023438, -2.5747146606445312),
#  (2.6676864624023438, -2.5747146606445312),
#  (2.6676864624023438, -0.5747146606445312),
#  (1.6676864624023438, -0.5747146606445312),
#  (1.6676864624023438, 1.4252853393554688),
#  (0.6676864624023438, 1.4252853393554688),
#  (0.6676864624023438, 3.4252853393554688),
#  (-0.33231353759765625, 3.4252853393554688),
#  (-0.33231353759765625, 4.425285339355469),
#  (-1.3323135375976562, 4.425285339355469),
#  (-1.3323135375976562, 6.425285339355469),
#  (-2.3323135375976562, 6.425285339355469),
#  (-2.3323135375976562, 8.425285339355469),
#  (-3.3323135375976562, 8.425285339355469),
#  (-3.3323135375976562, 9.425285339355469),
#  (-4.332313537597656, 9.425285339355469),
#  (-4.332313537597656, 11.425285339355469),
#  (-5.332313537597656, 11.425285339355469),
#  (-5.332313537597656, 13.425285339355469),
#  (-6.332313537597656, 13.425285339355469),
#  (-6.332313537597656, 15.425285339355469),
#  (-7.332313537597656, 15.425285339355469),
#  (-7.332313537597656, 17.42528533935547),
#  (-8.332313537597656, 17.42528533935547),
#  (-8.332313537597656, 22.42528533935547),
#  (-9.332313537597656, 22.42528533935547),
#  (-9.332313537597656, 30.42528533935547),
#  (-10.332313537597656, 30.42528533935547),
#  (-10.332313537597656, 43.42528533935547),
#  (-11.332313537597656, 43.42528533935547),
#  (-11.332313537597656, 49.42528533935547),
#  (-12.332313537597656, 49.42528533935547),
#  (-12.332313537597656, 53.42528533935547),
#  (-13.332313537597656, 53.42528533935547),
#  (-13.332313537597656, 68.42528533935547),
#  (-14.332313537597656, 68.42528533935547),
#  (-14.332313537597656, 79.42528533935547),
#  (-13.332313537597656, 79.42528533935547),
#  (-13.332313537597656, 81.42528533935547),
#  (-12.332313537597656, 81.42528533935547)]

# %% [markdown]
# ### verified coordinates in QGIS ##
#
# ![image-2.png](attachment:image-2.png)

# %%
# compute centerline of scarp using centerline class 
# 2nd param is the interpolation distance

centerline = Centerline(in_polygon, 31)
centerline

# %%
# returns a multi-linestring
centerline.geom_type
# Out:
# 'MultiLineString'

# %%
#list(centerline)

# %%
# Iterate through the multi-linestring to get the coordinates of each point
wpts_list = [list(x.coords) for x in list(centerline)]
wpts_list
# Out:
# [[(40.03725167979365, -55.95514944325323),
#   (37.834353129069015, -49.71360354953342)],
#  [(13.99853752623213, 21.431668318078877),
#   (22.60427689899278, -0.6973757833056595)],
#  [(7.653832558120229, 43.66961783305824),
#   (0.7041103034619454, 65.90872904796473)],
#  [(3.1813850925393297, 70.45039949460661),
#   (0.7041103034619454, 65.90872904796473)],
#  [(2.4900005119891198, 77.59470682695877),
#   (3.1813850925393297, 70.45039949460661)],
#  [(13.817999614803181, 21.56829160240349),
#   (6.365528189021049, 39.267911238636046)],
#  [(13.817999614803181, 21.56829160240349),
#   (13.99853752623213, 21.431668318078877)],
#  [(6.365528189021049, 39.267911238636046),
#   (7.653832558120229, 43.66961783305824)],
#  [(22.60427689899278, -0.6973757833056595),
#   (22.41301356520608, -1.5198081185884575)],
#  [(38.08976438448027, -48.8409484268783),
#   (30.245608540324426, -25.308480894410764)],
#  [(30.245608540324426, -25.308480894410764),
#   (30.501019795735672, -24.435825771755646)],
#  [(37.834353129069015, -49.71360354953342),
#   (38.08976438448027, -48.8409484268783)],
#  [(22.41301356520608, -1.5198081185884575),
#   (30.501019795735672, -24.435825771755646)]]

# %%
# merge into 1 linestring
from shapely.ops import linemerge
merged = linemerge(centerline)
merged

# %%
merged.geom_type
# Out:
# 'LineString'

# %%
#Get coordinates of the final linestring
x,y = merged.coords.xy
df = pd.DataFrame(list(zip(x,y)), columns=['LAT', 'LON'])
df
# Out:
#           LAT        LON
# 0   40.037252 -55.955149
# 1   37.834353 -49.713604
# 2   38.089764 -48.840948
# 3   30.245609 -25.308481
# 4   30.501020 -24.435826
# 5   22.413014  -1.519808
# 6   22.604277  -0.697376
# 7   13.998538  21.431668
# 8   13.818000  21.568292
# 9    6.365528  39.267911
# 10   7.653833  43.669618
# 11   0.704110  65.908729
# 12   3.181385  70.450399
# 13   2.490001  77.594707

# %%
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.LAT, df.LON))
gdf.to_file("cnterlin_merg.shp")
